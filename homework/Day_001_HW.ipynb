# %% [markdown]
# # Q1
# 選擇此問題 (https://www.kaggle.com/c/humpback-whale-identification)
# 1. 由於鯨魚濫捕情形過於嚴重，透過圖像辨識分析監測系統的圖像辨識鯨魚種類，並了解鯨魚群及棲息和及時移動狀況。
# 2. 資料提供者是一個線上平台 Happywhale，它們提供使用者上傳鯨魚照片並且進行自動辨識。
# 3. 資料型態為.jpg圖片檔。
# 4. 評估方式為Mean Average Precision @ 5 (MAP@5)。

# %% [markdown]
# # Q2
# 1. 預測不同時間/地點/天氣下的載客機率，用以分配不同時間和地點的車輛數。
# 2. 由叫車app後端資料庫蒐集。
# 3. GPS位置/叫車時間/降雨機率，皆為數值型態。
# 4. Label = 0: 車輛抵達該區域30分鐘以上無載客紀錄。
#    Label = 1: 車輛抵達該區域30分鐘以內有成功載客紀錄。
#    預測分類準確率/ROC。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.700

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum(pow(y - yp, 2)) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 232.594

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 232.594
# The Mean absolute error is 12.700
